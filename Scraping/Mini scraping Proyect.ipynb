# %%
import requests
import json
import urllib.request 
import html
import json
import csv 
import pymongo
import pandas as pd
from bs4 import BeautifulSoup

# %%
urls = "https://www.surtidor.com/sucursales"
print(requests.get(urls))
# Out:
# <Response [200]>

# %%
r=requests.get(urls)
soup = BeautifulSoup(r.content)
print(soup)
# Out:
# <!DOCTYPE HTML>
# ...

# %%
results = soup.find_all('div', class_="excerpt")
print(results[0])
# Out:
# <div class="excerpt"><p style="font-size: 11px; text-align: center;"><a href="https://www.surtidor.com/matriz-observatorio" title="Matriz Observatorio"> <b>Matriz Observatorio</b> </a><br/> Av. Observatorio No. 260<br/> Col. Daniel Garza<br/> Tel. 1450 9000 y 5237-0300<br/><br/> <a class="btn btn-default btn-sm read-more" href="https://www.surtidor.com/matriz-observatorio" target="_self" title="Matriz Observatorio"> Ver más </a></p></div>

# %%
for result in results:
        print(result.p.text)
# Out:
#  Matriz Observatorio  Av. Observatorio No. 260 Col. Daniel Garza Tel. 1450 9000 y 5237-0300  Ver más
#  Suc. Jalisco  Av. Jalisco No. 184-E Col. Tacubaya Tel. 5516-4532 y 5271-4566  Ver más
#  Suc. Tulyehualco  Av. Tláhuac No. 1479 Col. San Nicolás Tolentino Tel. 5237-0355 y 5426-6163  Ver más
#  Suc. Ermita  Calz. Ermita Iztapalapa No. 550 Col. Mexicaltzingo Tel. 5582-7310  Ver más
#  Suc. Xochimilco  Prolong. División del Norte No. 4991 Col. San Lorenzo La Cebada Tel. 5675-9202  Ver más
#  Suc. Tlalnepantla  Aut. México-Querétaro No. 3069-A Col. Tequesquinahuac Tel. 8628-8000 y 5390-3755  Ver más
#  Suc. Echegaray  Vía Gustavo Baz Prada Nte. No. 85-A Col. Santa María Nativitas Tel. 5360-6520  Ver más
#  Suc. Naucalpan  Blvd. Ávila Camacho No. 445 Col. San Andrés Atoto Tel. 5359-8383  Ver más
#  Suc. Vallejo  Calz. Vallejo No. 738 Col. Coltongo Tel. 5567-2900  Ver más
#  Suc. Toluca  José Ma. Pino Suárez Sur No. 1307 Col. Valle Verde Tel. 01 (722) 212-9030  Ver más
# ...

# %%
type(results)
# Out:
# bs4.element.ResultSet

# %%
data = [["Observatorio","Observatorio","Av. Observatorio No. 260","Miguel Hidalgo","Daniel Garza Tel","19.403744","-99.192502"], ["Jalisco","Jalisco","Av. Jalisco No. 184-E","Miguel Hidalgo","Tacubaya","32.441947","-114.72894"], ["Tulyehualco","Tulyehualco","Av. Tláhuac No. 1479","Iztapalapa","Col. San Nicolás Tolentino","59.9323","11.0203"],["Ermita  Calz","Ermita  Calz","Ermita Iztapalapa No. 550","Ermita Calz","Col. Mexicaltzingo","14.08333","79.58333"],["Xochimilco","Xochimilco","Prolong. División del Norte No. 4991","Xochimilco","Col. San Lorenzo La Cebada","21.11028","-100.52472"],["Tlalnepantla","Tlalnepantla","Aut. México-Querétaro No. 3069","Tlalnepantla de Baz","Col. Tequesquinahuac","19.527965","-99.174117"],["Echegaray","Echegaray"," Vía Gustavo Baz Prada Nte. No. 85-A","Naucalpan de Juárez,","Col. Santa María Nativitas","19.382027","-98.975994"],["Naucalpan","Naucalpan","Blvd. Ávila Camacho No. 445","Naucalpan de Juárez","Col. San Andrés Atoto","19.613849","-99.30569"],["Vallejo","Vallejo","Calz. Vallejo No. 738","Cuauhtemoc","Col. Coltongo","19.463495"," -99.142121"],["Toluca","Toluca","José Ma. Pino Suárez Sur No. 1307","Lerdo","Col. Valle Verde"," 19.284893 ","-99.615658"],["Monterrey","Monterrey","Av. Bernardo Reyes 5650","Col. Nuevo Leon","Col. Ferrocarrilera","25.714927"," -100.339025"]]
pd.DataFrame(data, columns=['Proveedor', 'Nombre sucursal', 'Dirección', 'Delegación o municipio','Colonia', 'LAT', 'LONG'])
# Out:
#        Proveedor Nombre sucursal                             Dirección  \
# 0   Observatorio    Observatorio              Av. Observatorio No. 260
# 1        Jalisco         Jalisco                 Av. Jalisco No. 184-E
# 2    Tulyehualco     Tulyehualco                  Av. Tláhuac No. 1479
# 3   Ermita  Calz    Ermita  Calz             Ermita Iztapalapa No. 550
# 4     Xochimilco      Xochimilco  Prolong. División del Norte No. 4991
# 5   Tlalnepantla    Tlalnepantla        Aut. México-Querétaro No. 3069
# 6      Echegaray       Echegaray   Vía Gustavo Baz Prada Nte. No. 85-A
# 7      Naucalpan       Naucalpan           Blvd. Ávila Camacho No. 445
# 8        Vallejo         Vallejo                 Calz. Vallejo No. 738
# 9         Toluca          Toluca     José Ma. Pino Suárez Sur No. 1307
# 10     Monterrey       Monterrey               Av. Bernardo Reyes 5650
#
#    Delegación o municipio                     Colonia          LAT  \
# ...

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
db = client.sucursales_db
collection = db.articles
